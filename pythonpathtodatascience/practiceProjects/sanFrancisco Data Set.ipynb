# %% [markdown]
# # Project 2 - San Francisco Data Analysis

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'/Users/gavinhenderson/Desktop/pythonpathtodatascience/practiceProjects/Salaries.csv')
df
# Out:
# /var/folders/_3/6ly0l9wx19d6s10hmwk0_tcr0000gn/T/ipykernel_16031/3713705208.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'/Users/gavinhenderson/Desktop/pythonpathtodatascience/practiceProjects/Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# ...

# %% [markdown]
# ### 1. Display Top 10 Rows of the dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of the dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# ### 3. Find Shape of our Dataset

# %%
df.shape
# Out:
# (148654, 13)

# %%
print("We have ", df.shape[0], ' Rows.')
print("We have ", df.shape[1], ' Columns.')
# Out:
# We have  148654  Rows.
# We have  13  Columns.

# %% [markdown]
# ### 4.  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# ### 6. 6. Drop ID, Notes, Agency, and Status Columns

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df = df.drop(['Id', 'Notes', 'Agency', 'Status'], axis = 1)    ## axis 0 is is for rows, axis 1 is for columns
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# ### 7. Get OVerall Statistics About the Dataframe

# %%
df.describe()    ## include= 'all' Include all includes categorical data
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %% [markdown]
# ### 8. Find Occurrence of The Employee Names  (Top 5)

# %%
df['EmployeeName'].value_counts(ascending=False).head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# ### 9. Find The Number of Unique Job Titles

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ### 10.Total Number of Job Titles Contain Captain

# %%
df[df['JobTitle'].str.contains('CAPTAIN', case=False)].count()  # Case = False makes it case insensitive
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# dtype: int64

# %% [markdown]
# ### 11. Display All the Employee Names From Fire Department

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df[df['JobTitle'].str.contains('Fire', case=False)].count()
# Out:
# EmployeeName        5879
# JobTitle            5879
# BasePay             5858
# OvertimePay         5879
# OtherPay            5879
# Benefits            4420
# TotalPay            5879
# TotalPayBenefits    5879
# Year                5879
# dtype: int64

# %% [markdown]
# ### 12. Find Minimum, Maximum, and Average BasePay

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
# Convert the 'BasePay' column to numeric, forcing errors to NaN
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')

# %%
df['BasePay'].max()
# Out:
# 319275.01

# %%
df['BasePay'].min()
# Out:
# -166.01

# %%
df['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# ### 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
import numpy as np
df ['EmployeeName'] = df['EmployeeName'].replace('Not provided', np.nan)

# %% [markdown]
# ### 14. Drop The Rows Having 5 Missing Values

# %%
df.isnull().sum(axis=1) ## axis = 1 sets it to row
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 148649    0
# 148650    2
# 148651    2
# 148652    2
# 148653    0
# Length: 148654, dtype: int64

# %%
df.drop(df[df.isnull().sum(axis=1) ==5].index, axis =0, inplace=True) ## inplace=True makes it permanent
## .index makes it so that it can locate the row

# %% [markdown]
# ### 15. Fidn Job Title of Alber Pardini

# %%
df[df['EmployeeName'] == 'Albert Pardini']['JobTitle']
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %% [markdown]
# ### 16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
df[df['EmployeeName'] == 'Albert Pardini']['TotalPayBenefits']
# Out:
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### 17.Display Name of The Person Having The Highest BasePay

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df[df['BasePay'].max() == df['BasePay']]['EmployeeName']    ## Need to have == if using an aggregate function
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# ### 18.Find Average BasePay of All Employee Per Year

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df.groupby('Year').mean()['BasePay']
# Out:
# /var/folders/_3/6ly0l9wx19d6s10hmwk0_tcr0000gn/T/ipykernel_16031/40158212.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Year').mean()['BasePay']
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 19. Find Average BasePay of Employee By Job Title

# %%
df.groupby('JobTitle').mean()['BasePay']
# Out:
# /var/folders/_3/6ly0l9wx19d6s10hmwk0_tcr0000gn/T/ipykernel_16031/2461860303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('JobTitle').mean()['BasePay']
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# ...

# %% [markdown]
# ### 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
df[df['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# ### 21. Find the top 5 most common jobs

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df['JobTitle'].value_counts(ascending=False).head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
